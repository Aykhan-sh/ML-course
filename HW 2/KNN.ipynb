# %%
from sklearn import datasets
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
import statsmodels.api as sm
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA
import matplotlib

# %%
X, y = datasets.load_iris(return_X_y=True, as_frame=True)
X
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# # Quick EDA

# %%
fig, ax = plt.subplots(nrows=4, ncols=2, figsize=(23,23))
for idx, i in enumerate(X.columns):
    ax[idx][0].set_title(i)
    sm.qqplot(X[i], line='s', ax=ax[idx][0])
    ax[idx][1].set_title(i)
    sns.histplot(X[i], ax=ax[idx][1])

# %%
plt.figure(figsize=(13,5))
plt.title("Class distribuion")
sns.countplot(x=y)
# Out:
# <AxesSubplot:title={'center':'Class distribuion'}, xlabel='target', ylabel='count'>

# %% [markdown]
# # KNN

# %%
X = (X-X.mean())/X.std()  # normalizing data

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=23, stratify=y)  # splitting data

# %%
model = KNeighborsClassifier()
model.fit(X_train, y_train)
preds = model.predict(X_test)
accuracy_score(y_test, preds)
# Out:
# 0.9666666666666667
